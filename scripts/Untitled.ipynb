# %%
x= "Java is not coffee"
y= "Java is not COFFEE"
if x!=y:
  print ("The two lines are not equal")
else:
  print(" Lines are equal")
# Out:
# The two lines are not equal

# %%
grade = int(input(("enter a number: ")))

if grade >= 90:
  print(" Grade = A")
elif grade >= 80:
    print("Grade = B")
else:
   print("fail")
# Out:
# enter a number:  50
# fail

# %%
growth_rate=0.95
one_Bug_volume=0.002
house_Volume= 2
populaion =4
total_bug_volume=population*one_Bug_volume
countWeek=0
while( total_bug_volume<house_volume)
   {newBugs=population*growth_rate
    newbugvolume=newbugs*one_Bug
